# %% [markdown]
# <a href="https://colab.research.google.com/github/soheilpaper/-tft-2.4-ili9341-STM32/blob/master/text-to-ppt-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall openai -y
# !pip install openai==0.28
# Out:
# Found existing installation: openai 1.7.1
# Uninstalling openai-1.7.1:
#   Successfully uninstalled openai-1.7.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import openai

# %%
# OpenAI API credentials
openai.api_key = "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" #'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'

# %%
response = openai.Image.create(
  prompt="problem/opportunity",
  n=1,
  size="1024x1024"
)
image_url = response['data'][0]['url']

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-kXFsBsz5Ihbs5TGtUs1hT2Vy/user-GuvSdf22AhQQFkRcENbLM2Tw/img-As4OaGbP79BoCr3abBgCsn75.png?st=2024-01-11T16%3A24%3A01Z&se=2024-01-11T18%3A24%3A01Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-01-11T02%3A22%3A42Z&ske=2024-01-12T02%3A22%3A42Z&sks=b&skv=2021-08-06&sig=/stpqeVpuiKqxWJrQROA%2BMeROUF5qSw%2B6TRHyhNWBBE%3D'

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
import openai

# Function to generate slide content from ChatGPT


def generate_slide_content(title):
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=f"{title}\n\n",
        max_tokens=200,
        n=1,
        stop=None,
        temperature=0.7
    )
    content = response.choices[0].text.strip()
    return content

# Function to create a slide with a title and content
# Function to create a slide with a title and content


def create_slide_with_title_and_content(presentation, title, content, point_to_format=None):
    # Title and Content slide layout
    slide_layout = presentation.slide_layouts[1]
    slide = presentation.slides.add_slide(slide_layout)

    # Set slide background
    slide.background.fill.solid()
    slide.background.fill.fore_color.rgb = RGBColor(
        255, 255, 255)  # White color

    title_placeholder = slide.shapes.title
    content_placeholder = slide.placeholders[1]

    # Set slide title font and color
    title_placeholder.text = title
    title_placeholder.text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT
    title_placeholder.text_frame.paragraphs[0].font.size = Pt(24)
    title_placeholder.text_frame.paragraphs[0].font.bold = True
    title_placeholder.text_frame.paragraphs[0].font.color.rgb = RGBColor(
        0, 0, 0)  # Black color

    # Set slide content font and color
    content_placeholder.text = content
    content_placeholder.text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT
    content_placeholder.text_frame.paragraphs[0].font.size = Pt(20)
    content_placeholder.text_frame.paragraphs[0].font.color.rgb = RGBColor(
        0, 0, 0)  # Black color

    # Automatically adjust font size to fit within the slide
    content_placeholder.text_frame.auto_size = True

    if point_to_format:
        # Find the position of the point to format within the content
        start_index = content.find(point_to_format)
        end_index = start_index + len(point_to_format)

        # Iterate over the paragraphs and runs in the content and set the format for the desired point
        for paragraph in content_placeholder.text_frame.paragraphs:
            for run in paragraph.runs:
                if point_to_format in run.text:
                    run.font.bold = True
                    run.font.color.rgb = RGBColor(0, 0, 255)  # Blue color


# Create a new presentation
presentation = Presentation()

ppt_title = input("Enter PPT Title :- ")

# Slide 1: Problem/Opportunity
problem_title = "Problem/Opportunity"
problem_content = generate_slide_content(problem_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=problem_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, problem_title, problem_content)

# Slide 2: Solution/Technology
solution_title = "Solution/Technology"
solution_content = generate_slide_content(solution_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=solution_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, solution_title, solution_content,'image.png')

# Slide 3: Current Status/Stage
status_title = "Current Status/Stage"
status_content = generate_slide_content(status_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=solution_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(presentation, status_title, status_content,'image.png')

# Slide 4: Product Demo
demo_title = "Product Demo"
demo_content = generate_slide_content(demo_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=demo_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(presentation, demo_title, demo_content,'image.png')

# Slide 5: Unique Value Proposition
value_proposition_title = "Unique Value Proposition"
value_proposition_content = generate_slide_content(
    value_proposition_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=value_proposition_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, value_proposition_title, value_proposition_content,'image.png')

# Slide 6: Competitive Advantage
advantage_title = "Competitive Advantage"
advantage_content = generate_slide_content(
    advantage_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=advantage_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, advantage_title, advantage_content,'image.png')

# Slide 7: Customer Segments & Market Size
segments_title = "Customer Segments & Market Size"
segments_content = generate_slide_content(segments_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=segments_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, segments_title, segments_content,'image.png')

# Slide 8: Channels
channels_title = "Channels"
channels_content = generate_slide_content(channels_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=channels_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, channels_title, channels_content,image_url)

# Slide 9: Revenue Streams
revenue_title = "Revenue Streams"
revenue_content = generate_slide_content(revenue_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=revenue_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, revenue_title, revenue_content,image_url)

# Slide 10: Cost of the Project
cost_title = "Cost of the Project"
cost_content = generate_slide_content(cost_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=cost_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(presentation, cost_title, cost_content,'image.png')

# Slide 11: Means of Finance
finance_title = "Means of Finance"
finance_content = generate_slide_content(finance_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=finance_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, finance_title, finance_content,'image.png')

# Slide 12: Key Metrics & Validation
metrics_title = "Key Metrics & Validation"
metrics_point = "Key Metric"  # Point to format
metrics_content = generate_slide_content(metrics_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=metrics_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, metrics_title, metrics_content, point_to_format=metrics_point,'image.png')

# Slide 13: THANK YOU
thankyou_slide_layout = presentation.slide_layouts[5]  # Blank slide layout
thankyou_slide = presentation.slides.add_slide(thankyou_slide_layout)
thankyou_textbox = thankyou_slide.shapes.add_textbox(
    Inches(2), Inches(2), Inches(6), Inches(2))
thankyou_frame = thankyou_textbox.text_frame
thankyou_frame.text = "THANK YOU"
thankyou_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
thankyou_frame.paragraphs[0].font.size = Pt(40)
thankyou_frame.paragraphs[0].font.bold = True
thankyou_textbox.fill.solid()
thankyou_textbox.fill.fore_color.rgb = RGBColor(0, 0, 0)  # Black color
thankyou_frame.paragraphs[0].font.color.rgb = RGBColor(
    255, 255, 255)  # White color

# Save the presentation to a file
presentation.save("presentation.pptx")
print("Presentation created successfully.")
# Out:
#   File "<ipython-input-9-cdd118fec430>", line 277
#     presentation, metrics_title, metrics_content, point_to_format=metrics_point,'image.png')
#                                                                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
# !pip install python-pptx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 14.4 MB/s eta 0:00:00
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
import openai

# Function to generate slide content from ChatGPT
model = "gpt-3.5-turbo"

def generate_slide_content(title):
    response = openai.Completion.create(
        engine= model , #'text-davinci-003',
        prompt=f"{title}\n\n",
        max_tokens=200,
        n=1,
        stop=None,
        temperature=0.7
    )
    content = response.choices[0].text.strip()
    return content

# Function to create a slide with a title and content
# Function to create a slide with a title and content


def create_slide_with_title_and_content(presentation, title, content, point_to_format=None):
    # Title and Content slide layout
    slide_layout = presentation.slide_layouts[1]
    slide = presentation.slides.add_slide(slide_layout)

    # Set slide background
    slide.background.fill.solid()
    slide.background.fill.fore_color.rgb = RGBColor(
        255, 255, 255)  # White color

    title_placeholder = slide.shapes.title
    content_placeholder = slide.placeholders[1]

    # Set slide title font and color
    title_placeholder.text = title
    title_placeholder.text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT
    title_placeholder.text_frame.paragraphs[0].font.size = Pt(24)
    title_placeholder.text_frame.paragraphs[0].font.bold = True
    title_placeholder.text_frame.paragraphs[0].font.color.rgb = RGBColor(
        0, 0, 0)  # Black color

    # Set slide content font and color
    content_placeholder.text = content
    content_placeholder.text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT
    content_placeholder.text_frame.paragraphs[0].font.size = Pt(20)
    content_placeholder.text_frame.paragraphs[0].font.color.rgb = RGBColor(
        0, 0, 0)  # Black color

    # Automatically adjust font size to fit within the slide
    content_placeholder.text_frame.auto_size = True

    if point_to_format:
        # Find the position of the point to format within the content
        start_index = content.find(point_to_format)
        end_index = start_index + len(point_to_format)

        # Iterate over the paragraphs and runs in the content and set the format for the desired point
        for paragraph in content_placeholder.text_frame.paragraphs:
            for run in paragraph.runs:
                if point_to_format in run.text:
                    run.font.bold = True
                    run.font.color.rgb = RGBColor(0, 0, 255)  # Blue color


# Create a new presentation
presentation = Presentation()

ppt_title = input("Enter PPT Title :- ")

# Slide 1: Problem/Opportunity
problem_title = "Problem/Opportunity"
problem_content = generate_slide_content(problem_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=problem_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
create_slide_with_title_and_content(
    presentation, problem_title, problem_content)

# Slide
# Out:
# Enter PPT Title :- پروپوزال فناوری نانو حباب برای گلخانه های هیدروپونیک
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-13-655f59d43c91> in <cell line: 77>()
#      75 # Slide 1: Problem/Opportunity
#      76 problem_title = "Problem/Opportunity"
# ---> 77 problem_content = generate_slide_content(problem_title + " in " + ppt_title)
#      78 response = openai.Image.create(
#      79     prompt=problem_title,
#
# <ipython-input-13-655f59d43c91> in generate_slide_content(title)
#       9
#      10 def generate_slide_content(title):
# ---> 11     response = openai.Completion.create(
#      12         engine= model , #'text-davinci-003',
#      13         prompt=f"{title}\n\n",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
import openai

# Function to generate slide content from ChatGPT
def generate_slide_content(title):
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=f"{title}\n\n",
        max_tokens=200,
        n=1,
        stop=None,
        temperature=0.7
    )
    content = response.choices[0].text.strip()
    return content

# Function to create a slide with a title and content
def create_slide_with_title_and_content(presentation, title, content, image_url):
    # Load the template presentation
    template = Presentation(template_path)
    slide_layout = template.slide_layouts[1]
    slide = presentation.slides.add_slide(slide_layout)

    # Set slide background from the template
    slide.background.copy_from(template.slides[0].background)

    # Add title to the slide
    title_placeholder = slide.shapes.title
    title_placeholder.text = title
    title_placeholder.text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT
    title_placeholder.text_frame.paragraphs[0].font.size = Pt(24)
    title_placeholder.text_frame.paragraphs[0].font.bold = True
    title_placeholder.text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 0, 0)  # Black color

    # Add content to the slide
    content_placeholder = slide.placeholders[1]
    content_placeholder.text = content
    content_placeholder.text_frame.paragraphs[0].alignment = PP_ALIGN.LEFT
    content_placeholder.text_frame.paragraphs[0].font.size = Pt(20)
    content_placeholder.text_frame.paragraphs[0].font.color.rgb = RGBColor(0, 0, 0)  # Black color

    # Automatically adjust font size to fit within the slide
    content_placeholder.text_frame.auto_size = True

    if image_url:
        # Add image to the slide
        slide_width = presentation.slide_width
        slide_height = presentation.slide_height

        # Calculate the position of the image
        image_width = int(slide_width * 0.5)
        image_height = int(slide_height * 0.5)
        image_left = int(slide_width * 0.5) + int(image_width * 0.5)
        image_top = int(slide_height * 0.5) - int(image_height * 0.5)

        slide.shapes.add_picture(image_url, image_left, image_top, image_width, image_height)

# Create a new presentation
presentation = Presentation()

ppt_title = input("Enter PPT Title: ")

# Slide 1: Problem/Opportunity
problem_title = "Problem/Opportunity"
problem_content = generate_slide_content(problem_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=problem_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_title_and_content(presentation, problem_title, problem_content, image_url,template_path)

# Slide 2: Solution/Technology
solution_title = "Solution/Technology"
solution_content = generate_slide_content(solution_title + " in " + ppt_title)
response = openai.Image.create(
    prompt=solution_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_title_and_content(presentation, solution_title, solution_content, image_url,template_path)

# Slide 3: Current Status/Stage
status_title = "Current Status/Stage"
status_content = generate_slide_content(status_title)
response = openai.Image.create(
    prompt= status_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, status_title, status_content, image_url, template_path)

# Slide 4: Product Demo
demo_title = "Product Demo"
demo_content = generate_slide_content(demo_title)
response = openai.Image.create(
    prompt=demo_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, demo_title, demo_content, image_url,template_path)

# Slide 5: Unique Value Proposition
value_title = "Unique Value Proposition"
value_content = generate_slide_content(value_title)
response = openai.Image.create(
    prompt= value_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = openai.Image.create(
    prompt=value_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, value_title, value_content, image_url,template_path)

# Slide 6: Competitive Advantage
advantage_title = "Competitive Advantage"
advantage_content = generate_slide_content(advantage_title)
response = openai.Image.create(
    prompt= advantage_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, advantage_title, advantage_content, image_url,template_path)

# Slide 7: Customer Segments & Market Size
segments_title = "Customer Segments & Market Size"
segments_content = generate_slide_content(segments_title)
response = openai.Image.create(
    prompt=segments_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = openai.Image.create(
    prompt=segments_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, segments_title, segments_content, image_url,template_path)

# Slide 8: Channels
channels_title = "Channels (Paths proposed to be taken to reach your target customer segments for)"
channels_content = generate_slide_content(channels_title)
response = openai.Image.create(
    prompt=channels_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, channels_title, channels_content, image_url,template_path)

# Slide 9: Revenue Streams
revenue_title = "Revenue Streams"
revenue_content = generate_slide_content(revenue_title)
response = openai.Image.create(
    prompt=revenue_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, revenue_title, revenue_content, image_url,template_path)

# Slide 10: Cost of the Project
cost_title = "Cost of the Project"
cost_content = generate_slide_content(cost_title)
response = openai.Image.create(
    prompt=cost_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, cost_title, cost_content, image_url,template_path)

# Slide 11: Means of Finance
finance_title = "Means of Finance:"
finance_content = generate_slide_content(finance_title)
response = openai.Image.create(
    prompt=finance_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, finance_title, finance_content, image_url,template_path)

# Slide 12: Key Metrics & Validation
metrics_title = "Key Metrics & Validation"
metrics_content = generate_slide_content(metrics_title)
response = openai.Image.create(
    prompt=metrics_title,
    n=1,
    size="1024x1024"
)
image_url = response['data'][0]['url']

# Save the image URL as a PNG file
response = requests.get(image_url)
with open('image.png', 'wb') as file:
    file.write(response.content)
image_url = "image.png"  # Replace with your actual image URL or path
create_slide_with_image(presentation, metrics_title, metrics_content, image_url,template_path)

# Slide 13: THANK YOU
thankyou_slide_layout = presentation.slide_layouts[5]  # Blank slide layout
thankyou_slide = presentation.slides.add_slide(thankyou_slide_layout,template_path)
thankyou_textbox = thankyou_slide.shapes.add_textbox(
    Inches(2), Inches(2), Inches(6), Inches(2))
thankyou_frame = thankyou_textbox.text_frame
thankyou_frame.text = "THANK YOU"
thankyou_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
thankyou_frame.paragraphs[0].font.size = Pt(40)
thankyou_frame.paragraphs[0].font.bold = True
thankyou_textbox.fill.solid()
thankyou_textbox.fill.fore_color.rgb = RGBColor(0, 0, 0)  # Black color
thankyou_frame.paragraphs[0].font.color.rgb = RGBColor(
    255, 255, 255)  # White color

# Save the presentation to a file
presentation.save("presentation.pptx")
print("Presentation created successfully.")
